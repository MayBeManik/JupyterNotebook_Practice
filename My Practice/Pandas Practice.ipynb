# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\krman\\OneDrive\\Desktop\\Marks.csv')
df
# Out:
#        STUDENT NAME  EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 0       MANIK KUMAR       19022511102    12031601     MODERN EUROPEAN DRAMA
# 1       MANIK KUMAR       19022511102    12031602  POSTCOLONIAL LITERATURES
# 2       MANIK KUMAR       19022511102    12037610      PARTITION LITERATURE
# 3       MANIK KUMAR       19022511102    12037614     LITERATURE AND CINEMA
# 4       MUKUL DUBEY       19022511114    12031601     MODERN EUROPEAN DRAMA
# 5       MUKUL DUBEY       19022511114    12031602  POSTCOLONIAL LITERATURES
# 6       MUKUL DUBEY       19022511114    12037610      PARTITION LITERATURE
# 7       MUKUL DUBEY       19022511114    12037614     LITERATURE AND CINEMA
# 8       SURAJ KUMAR       19022511140    12031601     MODERN EUROPEAN DRAMA
# 9       SURAJ KUMAR       19022511140    12031602  POSTCOLONIAL LITERATURES
# 10      SURAJ KUMAR       19022511140    12037610      PARTITION LITERATURE
# ...

# %%
df.shape
# Out:
# (36, 5)

# %%
df.head(4)
# Out:
#   STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 0  MANIK KUMAR        19022511102    12031601     MODERN EUROPEAN DRAMA
# 1  MANIK KUMAR        19022511102    12031602  POSTCOLONIAL LITERATURES
# 2  MANIK KUMAR        19022511102    12037610      PARTITION LITERATURE
# 3  MANIK KUMAR        19022511102    12037614     LITERATURE AND CINEMA
#
#    IA Marks\nout of 25
# 0                   14
# 1                   20
# 2                   18
# 3                   23

# %%
df.tail(4)
# Out:
#      STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 32  DEVANSH BISHT        19022511108    12031601     MODERN EUROPEAN DRAMA
# 33  DEVANSH BISHT        19022511108    12031602  POSTCOLONIAL LITERATURES
# 34  DEVANSH BISHT        19022511108    12037610      PARTITION LITERATURE
# 35  DEVANSH BISHT        19022511108    12037614     LITERATURE AND CINEMA
#
#     IA Marks\nout of 25
# 32                   17
# 33                   21
# 34                   13
# 35                   23

# %%
df['IA Marks\nout of 25'].max()
# Out:
# 23

# %%
df['IA Marks\nout of 25'].min()
# Out:
# 5

# %%
df['IA Marks\nout of 25'].mean()
# Out:
# 18.22222222222222

# %%
df['IA Marks\nout of 25'].std()
# Out:
# 4.182351430961235

# %%
df['IA Marks\nout of 25'].median()
# Out:
# 18.5

# %%
df['IA Marks\nout of 25'].mode()
# Out:
# 0    23
# Name: IA Marks\nout of 25, dtype: int64

# %%
df.describe()
# Out:
#         EXAM ROLL NUMBER    PAPER CODE  IA Marks\nout of 25
# count       3.600000e+01  3.600000e+01            36.000000
# mean        1.902251e+10  1.203461e+07            18.222222
# std         2.139752e+01  3.047880e+03             4.182351
# min         1.902251e+10  1.203160e+07             5.000000
# 25%         1.902251e+10  1.203160e+07            16.000000
# 50%         1.902251e+10  1.203461e+07            18.500000
# 75%         1.902251e+10  1.203761e+07            21.250000
# max         1.902251e+10  1.203761e+07            23.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
df.set_index("PAPER CODE")
# Out:
#                STUDENT NAME   EXAM ROLL NUMBER                PAPER NAME  \
# PAPER CODE
# 12031601        MANIK KUMAR        19022511102     MODERN EUROPEAN DRAMA
# 12031602        MANIK KUMAR        19022511102  POSTCOLONIAL LITERATURES
# 12037610        MANIK KUMAR        19022511102      PARTITION LITERATURE
# 12037614        MANIK KUMAR        19022511102     LITERATURE AND CINEMA
# 12031601        MUKUL DUBEY        19022511114     MODERN EUROPEAN DRAMA
# 12031602        MUKUL DUBEY        19022511114  POSTCOLONIAL LITERATURES
# 12037610        MUKUL DUBEY        19022511114      PARTITION LITERATURE
# 12037614        MUKUL DUBEY        19022511114     LITERATURE AND CINEMA
# 12031601        SURAJ KUMAR        19022511140     MODERN EUROPEAN DRAMA
# 12031602        SURAJ KUMAR        19022511140  POSTCOLONIAL LITERATURES
# 12037610        SURAJ KUMAR        19022511140      PARTITION LITERATURE
# 12037614        SURAJ KUMAR        19022511140     LITERATURE AND CINEMA
# ...

# %%
df
# Out:
#        STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 0       MANIK KUMAR        19022511102    12031601     MODERN EUROPEAN DRAMA
# 1       MANIK KUMAR        19022511102    12031602  POSTCOLONIAL LITERATURES
# 2       MANIK KUMAR        19022511102    12037610      PARTITION LITERATURE
# 3       MANIK KUMAR        19022511102    12037614     LITERATURE AND CINEMA
# 4       MUKUL DUBEY        19022511114    12031601     MODERN EUROPEAN DRAMA
# 5       MUKUL DUBEY        19022511114    12031602  POSTCOLONIAL LITERATURES
# 6       MUKUL DUBEY        19022511114    12037610      PARTITION LITERATURE
# 7       MUKUL DUBEY        19022511114    12037614     LITERATURE AND CINEMA
# 8       SURAJ KUMAR        19022511140    12031601     MODERN EUROPEAN DRAMA
# 9       SURAJ KUMAR        19022511140    12031602  POSTCOLONIAL LITERATURES
# 10      SURAJ KUMAR        19022511140    12037610      PARTITION LITERATURE
# ...

# %%
df[3:9]
# Out:
#   STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 3  MANIK KUMAR        19022511102    12037614     LITERATURE AND CINEMA
# 4  MUKUL DUBEY        19022511114    12031601     MODERN EUROPEAN DRAMA
# 5  MUKUL DUBEY        19022511114    12031602  POSTCOLONIAL LITERATURES
# 6  MUKUL DUBEY        19022511114    12037610      PARTITION LITERATURE
# 7  MUKUL DUBEY        19022511114    12037614     LITERATURE AND CINEMA
# 8  SURAJ KUMAR        19022511140    12031601     MODERN EUROPEAN DRAMA
#
#    IA Marks\nout of 25
# 3                   23
# 4                   17
# 5                   22
# 6                   19
# 7                   23
# 8                   14

# %%
df.columns
# Out:
# Index(['STUDENT NAME', ' EXAM ROLL NUMBER', 'PAPER CODE', 'PAPER NAME',
#        'IA Marks\nout of 25'],
#       dtype='object')

# %%
df['PAPER NAME']
# Out:
# 0        MODERN EUROPEAN DRAMA
# 1     POSTCOLONIAL LITERATURES
# 2         PARTITION LITERATURE
# 3        LITERATURE AND CINEMA
# 4        MODERN EUROPEAN DRAMA
# 5     POSTCOLONIAL LITERATURES
# 6         PARTITION LITERATURE
# 7        LITERATURE AND CINEMA
# 8        MODERN EUROPEAN DRAMA
# 9     POSTCOLONIAL LITERATURES
# 10        PARTITION LITERATURE
# 11       LITERATURE AND CINEMA
# 12       MODERN EUROPEAN DRAMA
# 13    POSTCOLONIAL LITERATURES
# 14        PARTITION LITERATURE
# 15       LITERATURE AND CINEMA
# 16       MODERN EUROPEAN DRAMA
# 17    POSTCOLONIAL LITERATURES
# 18        PARTITION LITERATURE
# 19       LITERATURE AND CINEMA
# 20       MODERN EUROPEAN DRAMA
# 21    POSTCOLONIAL LITERATURES
# 22        PARTITION LITERATURE
# 23       LITERATURE AND CINEMA
# 24       MODERN EUROPEAN DRAMA
# 25    POSTCOLONIAL LITERATURES
# 26        PARTITION LITERATURE
# 27       LITERATURE AND CINEMA
# 28       MODERN EUROPEAN DRAMA
# 29    POSTCOLONIAL LITERATURES
# ...

# %%
df[df.IA_Marks>=20]
# Out:
#        STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 1       MANIK KUMAR        19022511102    12031602  POSTCOLONIAL LITERATURES
# 3       MANIK KUMAR        19022511102    12037614     LITERATURE AND CINEMA
# 5       MUKUL DUBEY        19022511114    12031602  POSTCOLONIAL LITERATURES
# 7       MUKUL DUBEY        19022511114    12037614     LITERATURE AND CINEMA
# 9       SURAJ KUMAR        19022511140    12031602  POSTCOLONIAL LITERATURES
# 11      SURAJ KUMAR        19022511140    12037614     LITERATURE AND CINEMA
# 13     RISHAV MEHTO        19022511141    12031602  POSTCOLONIAL LITERATURES
# 15     RISHAV MEHTO        19022511141    12037614     LITERATURE AND CINEMA
# 19     SIMAR SALUJA        19022511138    12037614     LITERATURE AND CINEMA
# 21     ADITYA KUMAR        19022511103    12031602  POSTCOLONIAL LITERATURES
# 23     ADITYA KUMAR        19022511103    12037614     LITERATURE AND CINEMA
# ...

# %%
df[df.IA_Marks==df.IA_Marks.min()]
# Out:
#      STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE            PAPER NAME  \
# 26  STANZIN OTSAL        19022511151    12037610  PARTITION LITERATURE
#
#     IA_Marks
# 26         5

# %%
df[['STUDENT NAME','PAPER NAME','IA_Marks']][df.IA_Marks==df.IA_Marks.max()]
# Out:
#        STUDENT NAME             PAPER NAME  IA_Marks
# 3       MANIK KUMAR  LITERATURE AND CINEMA        23
# 7       MUKUL DUBEY  LITERATURE AND CINEMA        23
# 11      SURAJ KUMAR  LITERATURE AND CINEMA        23
# 15     RISHAV MEHTO  LITERATURE AND CINEMA        23
# 19     SIMAR SALUJA  LITERATURE AND CINEMA        23
# 23     ADITYA KUMAR  LITERATURE AND CINEMA        23
# 31  DHIRANJAN KUMAR  LITERATURE AND CINEMA        23
# 35    DEVANSH BISHT  LITERATURE AND CINEMA        23

# %%
new_df = df.fillna(0)
new_df
# Out:
#        STUDENT NAME   EXAM ROLL NUMBER  PAPER CODE                PAPER NAME  \
# 0       MANIK KUMAR        19022511102    12031601     MODERN EUROPEAN DRAMA
# 1       MANIK KUMAR        19022511102    12031602  POSTCOLONIAL LITERATURES
# 2       MANIK KUMAR        19022511102    12037610      PARTITION LITERATURE
# 3       MANIK KUMAR        19022511102    12037614     LITERATURE AND CINEMA
# 4       MUKUL DUBEY        19022511114    12031601     MODERN EUROPEAN DRAMA
# 5       MUKUL DUBEY        19022511114    12031602  POSTCOLONIAL LITERATURES
# 6       MUKUL DUBEY        19022511114    12037610      PARTITION LITERATURE
# 7       MUKUL DUBEY        19022511114    12037614     LITERATURE AND CINEMA
# 8       SURAJ KUMAR        19022511140    12031601     MODERN EUROPEAN DRAMA
# 9       SURAJ KUMAR        19022511140    12031602  POSTCOLONIAL LITERATURES
# 10      SURAJ KUMAR        19022511140    12037610      PARTITION LITERATURE
# ...

# %%
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#        STUDENT_NAME  EXAM_ROLL_NUMBER  PAPER_CODE                PAPER_NAME  \
# 0       MANIK KUMAR       19022511102    12031601     MODERN EUROPEAN DRAMA
# 1       MANIK KUMAR       19022511102    12031602  POSTCOLONIAL LITERATURES
# 2       MANIK KUMAR       19022511102    12037610      PARTITION LITERATURE
# 3       MANIK KUMAR       19022511102    12037614     LITERATURE AND CINEMA
# 4       MUKUL DUBEY       19022511114    12031601     MODERN EUROPEAN DRAMA
# 5       MUKUL DUBEY       19022511114    12031602  POSTCOLONIAL LITERATURES
# 6       MUKUL DUBEY       19022511114    12037610      PARTITION LITERATURE
# 7       MUKUL DUBEY       19022511114    12037614     LITERATURE AND CINEMA
# 8       SURAJ KUMAR       19022511140    12031601     MODERN EUROPEAN DRAMA
# 9       SURAJ KUMAR       19022511140    12031602  POSTCOLONIAL LITERATURES
# 10      SURAJ KUMAR       19022511140    12037610      PARTITION LITERATURE
# ...

# %%
print(df.dtypes)
# Out:
# STUDENT_NAME        object
# EXAM_ROLL_NUMBER     int64
# PAPER_CODE           int64
# PAPER_NAME          object
# IA_Marks             int64
# dtype: object

# %%
convert_dict = {
    'EXAM_ROLL_NUMBER':str,
    'PAPER_CODE':str,
    'STUDENT_NAME':str,
    'PAPER_NAME':str    
}
df = df.astype(convert_dict)
print(df.dtypes)
# Out:
# STUDENT_NAME        object
# EXAM_ROLL_NUMBER    object
# PAPER_CODE          object
# PAPER_NAME          object
# IA_Marks             int64
# dtype: object

# %%
g = df.groupby('PAPER_NAME')
for i,a in g:
    print(i)
    print(a)
# Out:
# LITERATURE AND CINEMA
#        STUDENT_NAME EXAM_ROLL_NUMBER PAPER_CODE             PAPER_NAME  \
# 3       MANIK KUMAR      19022511102   12037614  LITERATURE AND CINEMA
# 7       MUKUL DUBEY      19022511114   12037614  LITERATURE AND CINEMA
# 11      SURAJ KUMAR      19022511140   12037614  LITERATURE AND CINEMA
# 15     RISHAV MEHTO      19022511141   12037614  LITERATURE AND CINEMA
# 19     SIMAR SALUJA      19022511138   12037614  LITERATURE AND CINEMA
# 23     ADITYA KUMAR      19022511103   12037614  LITERATURE AND CINEMA
# 27    STANZIN OTSAL      19022511151   12037614  LITERATURE AND CINEMA
# 31  DHIRANJAN KUMAR      19022511087   12037614  LITERATURE AND CINEMA
# 35    DEVANSH BISHT      19022511108   12037614  LITERATURE AND CINEMA
#
#     IA_Marks
# 3         23
# 7         23
# 11        23
# 15        23
# 19        23
# 23        23
# 27        20
# 31        23
# 35        23
# MODERN EUROPEAN DRAMA
# ...

# %%
g.describe()
# Out:
#                          IA_Marks                                         \
#                             count       mean       std   min   25%   50%
# PAPER_NAME
# LITERATURE AND CINEMA         9.0  22.666667  1.000000  20.0  23.0  23.0
# MODERN EUROPEAN DRAMA         9.0  14.777778  2.333333  10.0  14.0  15.0
# PARTITION LITERATURE          9.0  15.222222  4.294700   5.0  14.0  17.0
# POSTCOLONIAL LITERATURES      9.0  20.222222  1.201850  18.0  20.0  20.0
#
#
#                            75%   max
# PAPER_NAME
# LITERATURE AND CINEMA     23.0  23.0
# MODERN EUROPEAN DRAMA     17.0  17.0
# PARTITION LITERATURE      18.0  19.0
# POSTCOLONIAL LITERATURES  21.0  22.0
